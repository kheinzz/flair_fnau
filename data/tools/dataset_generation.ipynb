# %%
import os
import random
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from rasterio.features import rasterize
from shapely.geometry import box
from sklearn.model_selection import train_test_split
import numpy as np
import csv
import logging

# Set the logging level to WARNING to suppress DEBUG messages
logging.getLogger('rasterio').setLevel(logging.WARNING)
# Define paths
shapefile_path = "C:/_GLOBAL/TRAVAIL/OCS/cosia/FLAIR-1-main/FLAIR-1-main/data/parking/osm_parking_final_2.gpkg"
raster_path = "C:/_GLOBAL/TRAVAIL/OCS/cosia/input/tm_ortho2022.vrt"
output_dir = "C:/_GLOBAL/TRAVAIL/OCS/cosia/FLAIR-1-main/FLAIR-1-main/data/parking/dataset2"
tile_size = 512  # Tile size in pixels

# Create output folders
folders = ["train/images", "train/labels", "val/images", "val/labels", "test/images", "test/labels"]
for folder in folders:
    os.makedirs(os.path.join(output_dir, folder), exist_ok=True)

# Load data
gdf = gpd.read_file(shapefile_path) 
with rasterio.open(raster_path) as src:
    raster_crs = src.crs

if gdf.crs != raster_crs:
    gdf = gdf.to_crs(raster_crs)

# Generate tiles based on parking lot polygons
tiles = []
for _, row in gdf.iterrows():
    center = row['geometry'].centroid
    tile = box(
        center.x - tile_size / 2, center.y - tile_size / 2,
        center.x + tile_size / 2, center.y + tile_size / 2
    )
    tiles.append(tile)

# Check for valid data in tile
def has_valid_data(tile_image, no_data_value=0):
    return np.any(tile_image != no_data_value)

# Rasterize geometries
def create_binary_mask(intersection, out_transform, tile_size):
    shapes = ((geom, 1) for geom in intersection.geometry)
    return rasterize(
        shapes=shapes, out_shape=(tile_size, tile_size),
        transform=out_transform, fill=0, dtype="uint8"
    )

# Process a single tile
def process_tile(tile, raster_path, gdf, output_dir, tile_index, split):
    # Create a GeoDataFrame for the current tile
    tile_gdf = gpd.GeoDataFrame({"geometry": [tile]}, crs=raster_crs)
    
    # Perform intersection to check overlap with parking polygons
    intersection = gpd.overlay(tile_gdf, gdf, how='intersection')
    
    if intersection.empty:
        # Log the absence of intersection and skip this tile
        print(f"Tile {tile_index:04d} has no intersection with polygons. Skipping.")
        return None

    # Proceed with raster masking if there is an intersection
    with rasterio.open(raster_path) as src:
        try:
            out_image, out_transform = mask(src, [tile], crop=True)
            out_image = out_image[:, :tile_size, :tile_size]
        except ValueError as e:
            # Handle tiles outside raster bounds
            print(f"Tile {tile_index:04d} is outside raster bounds: {e}")
            return None

    if not has_valid_data(out_image):
        print(f"Tile {tile_index:04d} contains no valid raster data. Skipping.")
        return None

    # Define folder based on split (train/val/test)
    folder_prefix = split if split else "train"
    image_tile_path = os.path.join(output_dir, f"{folder_prefix}/images/tile_{tile_index:04d}.tif")
    label_tile_path = os.path.join(output_dir, f"{folder_prefix}/labels/tile_{tile_index:04d}.tif")

    # Save the image tile
    with rasterio.open(
        image_tile_path, "w", driver="GTiff", height=tile_size,
        width=tile_size, count=src.count, dtype=out_image.dtype,
        crs=raster_crs, transform=out_transform
    ) as dst:
        dst.write(out_image)

    # Save the label tile
    binary_mask = create_binary_mask(intersection, out_transform, tile_size)
    with rasterio.open(
        label_tile_path, "w", driver="GTiff", height=tile_size,
        width=tile_size, count=1, dtype="uint8", crs=raster_crs, transform=out_transform
    ) as dst:
        dst.write(binary_mask, 1)

    return image_tile_path, label_tile_path

# Process tiles sequentially
tile_results = []
for tile_index, tile in enumerate(tiles):
    result = process_tile(tile, raster_path, gdf, output_dir, tile_index, "train")  # Initially assign to train
    if result:
        tile_results.append(result)

# Split dataset into train, val, test
image_tiles, label_tiles = zip(*tile_results)
train_images, temp_images, train_labels, temp_labels = train_test_split(
    image_tiles, label_tiles, test_size=0.3, random_state=42
)
val_images, test_images, val_labels, test_labels = train_test_split(
    temp_images, temp_labels, test_size=0.33, random_state=42
)

# Move the val and test images and labels to the appropriate folders
for val_index, val_image in enumerate(val_images):
    os.rename(val_image, val_image.replace("train", "val"))
    os.rename(val_labels[val_index], val_labels[val_index].replace("train", "val"))

for test_index, test_image in enumerate(test_images):
    os.rename(test_image, test_image.replace("train", "test"))
    os.rename(test_labels[test_index], test_labels[test_index].replace("train", "test"))

# Save CSV files
def write_csv(image_paths, label_paths, csv_path):
    with open(csv_path, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["image", "label"])
        writer.writerows(zip(image_paths, label_paths))

write_csv(train_images, train_labels, os.path.join(output_dir, "train.csv"))
write_csv(val_images, val_labels, os.path.join(output_dir, "val.csv"))
write_csv(test_images, test_labels, os.path.join(output_dir, "test.csv"))
# Out:
# Tile 0055 contains no valid raster data. Skipping.
# Tile 0057 contains no valid raster data. Skipping.
# Tile 0083 contains no valid raster data. Skipping.
# Tile 0244 contains no valid raster data. Skipping.
# Tile 0250 contains no valid raster data. Skipping.
# Tile 0251 contains no valid raster data. Skipping.
# Tile 0336 contains no valid raster data. Skipping.
# Tile 0337 contains no valid raster data. Skipping.
# Tile 0340 contains no valid raster data. Skipping.
# Tile 0341 contains no valid raster data. Skipping.
# Tile 0343 contains no valid raster data. Skipping.
# Tile 0344 contains no valid raster data. Skipping.
# Tile 0347 contains no valid raster data. Skipping.
# Tile 0351 contains no valid raster data. Skipping.
# Tile 0352 contains no valid raster data. Skipping.
# Tile 0358 contains no valid raster data. Skipping.
# Tile 0388 contains no valid raster data. Skipping.
# Tile 0428 contains no valid raster data. Skipping.
# Tile 0430 contains no valid raster data. Skipping.
# Tile 0468 contains no valid raster data. Skipping.
# Tile 0520 contains no valid raster data. Skipping.
# Tile 0695 contains no valid raster data. Skipping.
# Tile 0696 contains no valid raster data. Skipping.
# Tile 0724 contains no valid raster data. Skipping.
# Tile 0750 contains no valid raster data. Skipping.
# Tile 0751 contains no valid raster data. Skipping.
# Tile 0752 contains no valid raster data. Skipping.
# Tile 0753 contains no valid raster data. Skipping.
# Tile 0754 contains no valid raster data. Skipping.
# Tile 0760 contains no valid raster data. Skipping.
# Tile 0766 contains no valid raster data. Skipping.
# Tile 0781 contains no valid raster data. Skipping.
# Tile 0782 contains no valid raster data. Skipping.
# Tile 0796 contains no valid raster data. Skipping.
# Tile 0797 contains no valid raster data. Skipping.
# Tile 0836 contains no valid raster data. Skipping.
# Tile 0840 contains no valid raster data. Skipping.
# Tile 0841 contains no valid raster data. Skipping.
# Tile 0875 contains no valid raster data. Skipping.
# Tile 0941 contains no valid raster data. Skipping.
# Tile 0942 contains no valid raster data. Skipping.
# Tile 0945 contains no valid raster data. Skipping.
# Tile 0955 contains no valid raster data. Skipping.
# Tile 1091 contains no valid raster data. Skipping.
# Tile 1289 contains no valid raster data. Skipping.
# Tile 1327 contains no valid raster data. Skipping.
# Tile 1332 contains no valid raster data. Skipping.
# Tile 1336 contains no valid raster data. Skipping.
# Tile 1337 contains no valid raster data. Skipping.
# Tile 1341 contains no valid raster data. Skipping.
# Tile 1342 contains no valid raster data. Skipping.
# Tile 1343 contains no valid raster data. Skipping.
# Tile 1344 contains no valid raster data. Skipping.
# Tile 1383 contains no valid raster data. Skipping.
# Tile 1384 contains no valid raster data. Skipping.
# Tile 1410 contains no valid raster data. Skipping.
# Tile 1560 contains no valid raster data. Skipping.
# Tile 1561 contains no valid raster data. Skipping.
# Tile 1625 contains no valid raster data. Skipping.
# Tile 1822 contains no valid raster data. Skipping.
# Tile 1823 contains no valid raster data. Skipping.
# Tile 1922 contains no valid raster data. Skipping.
# Tile 1923 contains no valid raster data. Skipping.
# Tile 1924 contains no valid raster data. Skipping.
# Tile 1946 contains no valid raster data. Skipping.
# Tile 1947 contains no valid raster data. Skipping.
# Tile 1948 contains no valid raster data. Skipping.
# Tile 1949 contains no valid raster data. Skipping.
# Tile 1963 contains no valid raster data. Skipping.
# Tile 1996 contains no valid raster data. Skipping.
# Tile 2037 contains no valid raster data. Skipping.
# Tile 2045 contains no valid raster data. Skipping.
# Tile 2046 contains no valid raster data. Skipping.
# Tile 2176 contains no valid raster data. Skipping.
# Tile 2210 contains no valid raster data. Skipping.
# Tile 2267 contains no valid raster data. Skipping.
# Tile 2276 contains no valid raster data. Skipping.
# Tile 2280 contains no valid raster data. Skipping.
# Tile 2289 contains no valid raster data. Skipping.
# Tile 2310 contains no valid raster data. Skipping.
# Tile 2311 contains no valid raster data. Skipping.
# Tile 2312 contains no valid raster data. Skipping.
# Tile 2313 contains no valid raster data. Skipping.
# Tile 2314 contains no valid raster data. Skipping.
# Tile 2315 contains no valid raster data. Skipping.
# Tile 2316 contains no valid raster data. Skipping.
# Tile 2317 contains no valid raster data. Skipping.
# Tile 2318 contains no valid raster data. Skipping.
# Tile 2319 contains no valid raster data. Skipping.
# Tile 2332 contains no valid raster data. Skipping.
# Tile 2334 contains no valid raster data. Skipping.
# Tile 2487 contains no valid raster data. Skipping.
# Tile 2488 contains no valid raster data. Skipping.
# Tile 2489 contains no valid raster data. Skipping.
# Tile 2658 contains no valid raster data. Skipping.
# Tile 2830 contains no valid raster data. Skipping.
# Tile 2831 contains no valid raster data. Skipping.
# Tile 2841 contains no valid raster data. Skipping.
# Tile 2949 contains no valid raster data. Skipping.
# Tile 3186 contains no valid raster data. Skipping.
# Tile 3187 contains no valid raster data. Skipping.
# Tile 3188 contains no valid raster data. Skipping.
# Tile 3189 contains no valid raster data. Skipping.
# Tile 3190 contains no valid raster data. Skipping.
# Tile 3192 is outside raster bounds: Input shapes do not overlap raster.
# Tile 3193 contains no valid raster data. Skipping.
# Tile 3195 contains no valid raster data. Skipping.
# Tile 3196 contains no valid raster data. Skipping.
# Tile 3197 contains no valid raster data. Skipping.
# Tile 3198 contains no valid raster data. Skipping.
# Tile 3199 contains no valid raster data. Skipping.
# Tile 3201 contains no valid raster data. Skipping.
# Tile 3202 contains no valid raster data. Skipping.
# Tile 3203 contains no valid raster data. Skipping.
# Tile 3335 contains no valid raster data. Skipping.
# Tile 3355 contains no valid raster data. Skipping.
# Tile 3356 contains no valid raster data. Skipping.
# Tile 3357 contains no valid raster data. Skipping.
# Tile 3762 contains no valid raster data. Skipping.
# Tile 3931 contains no valid raster data. Skipping.
# Tile 3932 contains no valid raster data. Skipping.
# Tile 4037 contains no valid raster data. Skipping.
# Tile 4057 contains no valid raster data. Skipping.
# Tile 4093 contains no valid raster data. Skipping.
# Tile 4447 contains no valid raster data. Skipping.
# Tile 4476 contains no valid raster data. Skipping.
# Tile 4771 contains no valid raster data. Skipping.
# Tile 4910 contains no valid raster data. Skipping.
# Tile 4911 contains no valid raster data. Skipping.
# Tile 4912 contains no valid raster data. Skipping.
# Tile 4913 contains no valid raster data. Skipping.
# Tile 4914 contains no valid raster data. Skipping.
# Tile 4915 contains no valid raster data. Skipping.
# Tile 4916 contains no valid raster data. Skipping.
# Tile 4917 contains no valid raster data. Skipping.
# Tile 4918 contains no valid raster data. Skipping.
# Tile 4919 contains no valid raster data. Skipping.
# Tile 4920 contains no valid raster data. Skipping.
# Tile 4921 contains no valid raster data. Skipping.
# Tile 4922 contains no valid raster data. Skipping.
# Tile 4923 contains no valid raster data. Skipping.
# Tile 4924 contains no valid raster data. Skipping.
# Tile 4925 contains no valid raster data. Skipping.
# Tile 4926 contains no valid raster data. Skipping.
# Tile 4927 contains no valid raster data. Skipping.
# Tile 4928 contains no valid raster data. Skipping.
# Tile 4929 contains no valid raster data. Skipping.
# Tile 4930 contains no valid raster data. Skipping.
# Tile 4931 contains no valid raster data. Skipping.
# Tile 4932 contains no valid raster data. Skipping.
# Tile 5133 contains no valid raster data. Skipping.
# Tile 5203 contains no valid raster data. Skipping.
# Tile 5204 contains no valid raster data. Skipping.
# Tile 5205 contains no valid raster data. Skipping.
# Tile 5249 contains no valid raster data. Skipping.
# Tile 5250 contains no valid raster data. Skipping.
# Tile 5251 contains no valid raster data. Skipping.
# Tile 5276 contains no valid raster data. Skipping.
# Tile 5277 contains no valid raster data. Skipping.
# Tile 5278 contains no valid raster data. Skipping.
# Tile 5279 contains no valid raster data. Skipping.
# Tile 5552 contains no valid raster data. Skipping.
# Tile 5553 contains no valid raster data. Skipping.
# Tile 5554 contains no valid raster data. Skipping.
# Tile 5555 contains no valid raster data. Skipping.
# Tile 5556 contains no valid raster data. Skipping.
# Tile 5557 contains no valid raster data. Skipping.
# Tile 5571 contains no valid raster data. Skipping.
# Tile 5599 contains no valid raster data. Skipping.
# Tile 5620 contains no valid raster data. Skipping.
# Tile 5621 contains no valid raster data. Skipping.
# Tile 5662 contains no valid raster data. Skipping.
# Tile 5663 contains no valid raster data. Skipping.
# Tile 5798 contains no valid raster data. Skipping.
# Tile 5799 contains no valid raster data. Skipping.
# Tile 5800 contains no valid raster data. Skipping.
# Tile 5801 contains no valid raster data. Skipping.
# Tile 5802 contains no valid raster data. Skipping.
# Tile 5803 contains no valid raster data. Skipping.
# Tile 5804 contains no valid raster data. Skipping.
# Tile 5805 contains no valid raster data. Skipping.
# Tile 5833 contains no valid raster data. Skipping.
# Tile 5834 contains no valid raster data. Skipping.
# Tile 5835 contains no valid raster data. Skipping.
# Tile 5836 contains no valid raster data. Skipping.
# Tile 5837 contains no valid raster data. Skipping.
# Tile 5838 contains no valid raster data. Skipping.
# Tile 5839 contains no valid raster data. Skipping.
# Tile 5840 contains no valid raster data. Skipping.
# Tile 5841 contains no valid raster data. Skipping.
# Tile 5842 contains no valid raster data. Skipping.
# Tile 5862 contains no valid raster data. Skipping.
# Tile 5863 contains no valid raster data. Skipping.
# Tile 5871 contains no valid raster data. Skipping.
# Tile 5872 contains no valid raster data. Skipping.
# Tile 6024 contains no valid raster data. Skipping.
# Tile 6027 contains no valid raster data. Skipping.
# Tile 6028 contains no valid raster data. Skipping.
# Tile 6033 contains no valid raster data. Skipping.
# Tile 6037 contains no valid raster data. Skipping.
# Tile 6038 contains no valid raster data. Skipping.
# Tile 6042 contains no valid raster data. Skipping.
# Tile 6238 contains no valid raster data. Skipping.
